# %%
# !gdown --id 1MactbX3-I43bJx_e_X2144bpOlBaaF7L
# !gdown --id 1VwKlE6m9G2b2M9pMYbJniwmVl74gcIkw
# Out:
# /usr/local/lib/python3.10/dist-packages/gdown/cli.py:121: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1MactbX3-I43bJx_e_X2144bpOlBaaF7L
# To: /content/test.csv
# 100% 2.05M/2.05M [00:00<00:00, 142MB/s]
# /usr/local/lib/python3.10/dist-packages/gdown/cli.py:121: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1VwKlE6m9G2b2M9pMYbJniwmVl74gcIkw
# To: /content/BOW_model.joblib
# 100% 11.3M/11.3M [00:00<00:00, 49.9MB/s]

# %%
import pandas as pd
import joblib
from sklearn import metrics

# %%
test_df = pd.read_csv('test.csv')

# %%
# Load model Preprocessing and Model
loaded_model = joblib.load("BOW_model.joblib")
loaded_model
# Out:
# Pipeline(steps=[('countvectorizer', CountVectorizer()),
#                 ('logisticregression', LogisticRegression())])

# %%
def print_report(loaded_model, x_test, y_test):
    y_pred = loaded_model.predict(x_test)
    report = metrics.classification_report(y_test, y_pred)
    print(report)
    print("accuracy: {:0.3f}".format(metrics.accuracy_score(y_test, y_pred)))

print_report(loaded_model, test_df.text, test_df.dialect)
# Out:
#               precision    recall  f1-score   support
#
#           EG       0.84      0.91      0.88      5777
#           LB       0.85      0.85      0.85      2770
#           LY       0.79      0.82      0.81      3566
#           MA       0.86      0.66      0.75      1168
#           SD       0.82      0.61      0.70      1482
#
#     accuracy                           0.83     14763
#    macro avg       0.83      0.77      0.80     14763
# weighted avg       0.83      0.83      0.83     14763
#
# accuracy: 0.829
